# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_csv('../test/GPU_test_Complete_1.csv')
dat1 = pd.DataFrame(data1)
dat1["test"] = 1
data2 = pd.read_csv('../test/GPU_test_Complete_2.csv')
dat2 = pd.DataFrame(data2)
dat2["test"] = 3
data = pd.concat([dat1, dat2], ignore_index=True)
#data= pd.read_csv('../test/GPU_test_Complete.csv')
fields_to_plot = ["BenElechi1.mtx", "degme.mtx", "mawi_201512012345.mtx","rail2586.mtx","specular.mtx"] #Matrix considered

colors = ['red', 'blue', 'green', 'yellow','orange','pink'] #Colors for the graph.

# %%
dfo = pd.DataFrame(data)
dfo = dfo[dfo["id"] == "COO_OLD"]
ResultCOO_OLD = {}
for field in fields_to_plot:
    df = dfo[dfo["matrix"] == field]
    df = df[df.mu == df.mu.min()]
    ResultCOO_OLD[field] = {"Msparsity":df["Msparsity"].iloc[0],"Mtype":df["Mtype"].iloc[0],"Mpattern":df["Mpattern"].iloc[0],"sort":df["sort"].iloc[0],"blockSize":int(df["blockSize"].iloc[0]),"mu":float(df["mu"].iloc[0]),"nMemAcGL":int(df["nMemAcGL"].iloc[0]),"nMemAcSH":int(df["nMemAcSH"].iloc[0]),"AI":float(df["AI"].iloc[0]),"Iperf":float(df["Iperf"].iloc[0]),"flops":float(df["flops"].iloc[0]),"effBandGL":float(df["effBandGL"].iloc[0]),"effBandSH":float(df["effBandSH"].iloc[0]),"N_STREAM":int(df["N_STREAM"].iloc[0]),"test":int(df["test"].iloc[0])}
    #"test":float(df["test"].iloc[0])

ResultCOO_OLD_1 = {}
for field in fields_to_plot:
    df = dfo[dfo["matrix"] == field]
    df = df[df["test"] == 1]
    df = df[df.mu == df.mu.min()]
    ResultCOO_OLD_1[field] = {"Msparsity":df["Msparsity"].iloc[0],"Mtype":df["Mtype"].iloc[0],"Mpattern":df["Mpattern"].iloc[0],"sort":df["sort"].iloc[0],"blockSize":int(df["blockSize"].iloc[0]),"mu":float(df["mu"].iloc[0]),"nMemAcGL":int(df["nMemAcGL"].iloc[0]),"nMemAcSH":int(df["nMemAcSH"].iloc[0]),"AI":float(df["AI"].iloc[0]),"Iperf":float(df["Iperf"].iloc[0]),"flops":float(df["flops"].iloc[0]),"effBandGL":float(df["effBandGL"].iloc[0]),"effBandSH":float(df["effBandSH"].iloc[0]),"N_STREAM":int(df["N_STREAM"].iloc[0]),"test":int(df["test"].iloc[0])}
    #"test":float(df["test"].iloc[0])

ResultCOO_OLD_2 = {}
for field in fields_to_plot:
    df = dfo[dfo["matrix"] == field]
    df = df[df["test"] == 3]
    df = df[df.mu == df.mu.min()]
    ResultCOO_OLD_2[field] = {"Msparsity":df["Msparsity"].iloc[0],"Mtype":df["Mtype"].iloc[0],"Mpattern":df["Mpattern"].iloc[0],"sort":df["sort"].iloc[0],"blockSize":int(df["blockSize"].iloc[0]),"mu":float(df["mu"].iloc[0]),"nMemAcGL":int(df["nMemAcGL"].iloc[0]),"nMemAcSH":int(df["nMemAcSH"].iloc[0]),"AI":float(df["AI"].iloc[0]),"Iperf":float(df["Iperf"].iloc[0]),"flops":float(df["flops"].iloc[0]),"effBandGL":float(df["effBandGL"].iloc[0]),"effBandSH":float(df["effBandSH"].iloc[0]),"N_STREAM":int(df["N_STREAM"].iloc[0]),"test":int(df["test"].iloc[0])}
    #"test":float(df["test"].iloc[0])

print(ResultCOO_OLD)
# Out:
# {'BenElechi1.mtx': {'Msparsity': 'C', 'Mtype': 'R', 'Mpattern': 'S', 'sort': 'SortC', 'blockSize': 64, 'mu': 0.000221, 'nMemAcGL': 160756432, 'nMemAcSH': 107170960, 'AI': 0.1, 'Iperf': 93.3, 'flops': 60.543621, 'effBandGL': 726.523413, 'effBandSH': 484.348966, 'N_STREAM': 1, 'test': 1}, 'degme.mtx': {'Msparsity': 'C', 'Mtype': 'R', 'Mpattern': 'G', 'sort': 'SortR', 'blockSize': 64, 'mu': 0.000528, 'nMemAcGL': 132517512, 'nMemAcSH': 130040448, 'AI': 0.1, 'Iperf': 93.3, 'flops': 30.780712, 'effBandGL': 250.936283, 'effBandSH': 246.245694, 'N_STREAM': 1, 'test': 3}, 'mawi_201512012345.mtx': {'Msparsity': 'C', 'Mtype': 'I', 'Mpattern': 'S', 'sort': 'SortR', 'blockSize': 128, 'mu': 0.000945, 'nMemAcGL': 386088880, 'nMemAcSH': 304322560, 'AI': 0.1, 'Iperf': 93.3, 'flops': 40.259996, 'effBandGL': 408.617408, 'effBandSH': 322.079972, 'N_STREAM': 1, 'test': 1}, 'rail2586.mtx': {'Msparsity': 'C', 'Mtype': 'I', 'Mpattern': 'G', 'sort': 'SortR', 'blockSize': 128, 'mu': 0.000654, 'nMemAcGL': 1287
# ...

# %%
dfo = pd.DataFrame(data)
dfo = dfo[dfo["id"] == "COO_NEW_1"]
ResultCOO_NEW_1 = {}
for field in fields_to_plot:
    df = dfo[dfo["matrix"] == field]
    df = df[df.mu == df.mu.min()]
    ResultCOO_NEW_1[field] = {"Msparsity":df["Msparsity"].iloc[0],"Mtype":df["Mtype"].iloc[0],"Mpattern":df["Mpattern"].iloc[0],"sort":df["sort"].iloc[0],"blockSize":int(df["blockSize"].iloc[0]),"mu":float(df["mu"].iloc[0]),"nMemAcGL":int(df["nMemAcGL"].iloc[0]),"nMemAcSH":int(df["nMemAcSH"].iloc[0]),"AI":float(df["AI"].iloc[0]),"Iperf":float(df["Iperf"].iloc[0]),"flops":float(df["flops"].iloc[0]),"effBandGL":float(df["effBandGL"].iloc[0]),"effBandSH":float(df["effBandSH"].iloc[0]),"N_STREAM":int(df["N_STREAM"].iloc[0]),"test":int(df["test"].iloc[0])}
    #"test":float(df["test"].iloc[0])

ResultCOO_NEW_1_1 = {}
for field in fields_to_plot:
    df = dfo[dfo["matrix"] == field]
    df = df[df["test"] == 1]
    df = df[df.mu == df.mu.min()]
    ResultCOO_NEW_1_1[field] = {"Msparsity":df["Msparsity"].iloc[0],"Mtype":df["Mtype"].iloc[0],"Mpattern":df["Mpattern"].iloc[0],"sort":df["sort"].iloc[0],"blockSize":int(df["blockSize"].iloc[0]),"mu":float(df["mu"].iloc[0]),"nMemAcGL":int(df["nMemAcGL"].iloc[0]),"nMemAcSH":int(df["nMemAcSH"].iloc[0]),"AI":float(df["AI"].iloc[0]),"Iperf":float(df["Iperf"].iloc[0]),"flops":float(df["flops"].iloc[0]),"effBandGL":float(df["effBandGL"].iloc[0]),"effBandSH":float(df["effBandSH"].iloc[0]),"N_STREAM":int(df["N_STREAM"].iloc[0]),"test":int(df["test"].iloc[0])}
    #"test":float(df["test"].iloc[0])

ResultCOO_NEW_1_2 = {}
for field in fields_to_plot:
    df = dfo[dfo["matrix"] == field]
    df = df[df["test"] == 3]
    df = df[df.mu == df.mu.min()]
    ResultCOO_NEW_1_2[field] = {"Msparsity":df["Msparsity"].iloc[0],"Mtype":df["Mtype"].iloc[0],"Mpattern":df["Mpattern"].iloc[0],"sort":df["sort"].iloc[0],"blockSize":int(df["blockSize"].iloc[0]),"mu":float(df["mu"].iloc[0]),"nMemAcGL":int(df["nMemAcGL"].iloc[0]),"nMemAcSH":int(df["nMemAcSH"].iloc[0]),"AI":float(df["AI"].iloc[0]),"Iperf":float(df["Iperf"].iloc[0]),"flops":float(df["flops"].iloc[0]),"effBandGL":float(df["effBandGL"].iloc[0]),"effBandSH":float(df["effBandSH"].iloc[0]),"N_STREAM":int(df["N_STREAM"].iloc[0]),"test":int(df["test"].iloc[0])}
    #"test":float(df["test"].iloc[0])
print(ResultCOO_NEW_1)
# Out:
# {'BenElechi1.mtx': {'Msparsity': 'C', 'Mtype': 'R', 'Mpattern': 'S', 'sort': 'SortR', 'blockSize': 512, 'mu': 0.000195, 'nMemAcGL': 0, 'nMemAcSH': 0, 'AI': 0.0, 'Iperf': 0.0, 'flops': 68.584549, 'effBandGL': 0.0, 'effBandSH': 0.0, 'N_STREAM': 2, 'test': 3}, 'degme.mtx': {'Msparsity': 'C', 'Mtype': 'R', 'Mpattern': 'G', 'sort': 'SortR', 'blockSize': 512, 'mu': 0.000238, 'nMemAcGL': 0, 'nMemAcSH': 0, 'AI': 0.0, 'Iperf': 0.0, 'flops': 68.238139, 'effBandGL': 0.0, 'effBandSH': 0.0, 'N_STREAM': 2, 'test': 3}, 'mawi_201512012345.mtx': {'Msparsity': 'C', 'Mtype': 'I', 'Mpattern': 'S', 'sort': 'SortR', 'blockSize': 1024, 'mu': 0.000733, 'nMemAcGL': 0, 'nMemAcSH': 0, 'AI': 0.0, 'Iperf': 0.0, 'flops': 51.879508, 'effBandGL': 0.0, 'effBandSH': 0.0, 'N_STREAM': 2, 'test': 3}, 'rail2586.mtx': {'Msparsity': 'C', 'Mtype': 'I', 'Mpattern': 'G', 'sort': 'SortR', 'blockSize': 512, 'mu': 0.000244, 'nMemAcGL': 0, 'nMemAcSH': 0, 'AI': 0.0, 'Iperf': 0.0, 'flops': 65.552625, 'effBandGL': 0.0, 'effBandSH': 
# ...

# %%
dfo = pd.DataFrame(data)
dfo = dfo[dfo["id"] == "COO_CUSPARSE"]
ResultCOO_CUSPARSE = {}
for field in fields_to_plot:
    df = dfo[dfo["matrix"] == field]
    df = df[df.mu == df.mu.min()]
    ResultCOO_CUSPARSE[field] = {"Msparsity":df["Msparsity"].iloc[0],"Mtype":df["Mtype"].iloc[0],"Mpattern":df["Mpattern"].iloc[0],"sort":df["sort"].iloc[0],"blockSize":int(df["blockSize"].iloc[0]),"mu":float(df["mu"].iloc[0]),"nMemAcGL":int(df["nMemAcGL"].iloc[0]),"nMemAcSH":int(df["nMemAcSH"].iloc[0]),"AI":float(df["AI"].iloc[0]),"Iperf":float(df["Iperf"].iloc[0]),"flops":float(df["flops"].iloc[0]),"effBandGL":float(df["effBandGL"].iloc[0]),"effBandSH":float(df["effBandSH"].iloc[0]),"N_STREAM":int(df["N_STREAM"].iloc[0]),"test":int(df["test"].iloc[0])}
    #"test":float(df["test"].iloc[0])

ResultCOO_CUSPARSE_1 = {}
for field in fields_to_plot:
    df = dfo[dfo["matrix"] == field]
    df = df[df["test"] == 1]
    df = df[df.mu == df.mu.min()]
    ResultCOO_CUSPARSE_1[field] = {"Msparsity":df["Msparsity"].iloc[0],"Mtype":df["Mtype"].iloc[0],"Mpattern":df["Mpattern"].iloc[0],"sort":df["sort"].iloc[0],"blockSize":int(df["blockSize"].iloc[0]),"mu":float(df["mu"].iloc[0]),"nMemAcGL":int(df["nMemAcGL"].iloc[0]),"nMemAcSH":int(df["nMemAcSH"].iloc[0]),"AI":float(df["AI"].iloc[0]),"Iperf":float(df["Iperf"].iloc[0]),"flops":float(df["flops"].iloc[0]),"effBandGL":float(df["effBandGL"].iloc[0]),"effBandSH":float(df["effBandSH"].iloc[0]),"N_STREAM":int(df["N_STREAM"].iloc[0]),"test":int(df["test"].iloc[0])}
    #"test":float(df["test"].iloc[0])

ResultCOO_CUSPARSE_2 = {}
for field in fields_to_plot:
    df = dfo[dfo["matrix"] == field]
    df = df[df["test"] == 3]
    df = df[df.mu == df.mu.min()]
    ResultCOO_CUSPARSE_2[field] = {"Msparsity":df["Msparsity"].iloc[0],"Mtype":df["Mtype"].iloc[0],"Mpattern":df["Mpattern"].iloc[0],"sort":df["sort"].iloc[0],"blockSize":int(df["blockSize"].iloc[0]),"mu":float(df["mu"].iloc[0]),"nMemAcGL":int(df["nMemAcGL"].iloc[0]),"nMemAcSH":int(df["nMemAcSH"].iloc[0]),"AI":float(df["AI"].iloc[0]),"Iperf":float(df["Iperf"].iloc[0]),"flops":float(df["flops"].iloc[0]),"effBandGL":float(df["effBandGL"].iloc[0]),"effBandSH":float(df["effBandSH"].iloc[0]),"N_STREAM":int(df["N_STREAM"].iloc[0]),"test":int(df["test"].iloc[0])}
    #"test":float(df["test"].iloc[0])
print(ResultCOO_CUSPARSE)
# Out:
# {'BenElechi1.mtx': {'Msparsity': 'C', 'Mtype': 'R', 'Mpattern': 'S', 'sort': 'SortR', 'blockSize': -1, 'mu': 0.000129, 'nMemAcGL': 0, 'nMemAcSH': 0, 'AI': 0.0, 'Iperf': 0.0, 'flops': 103.636964, 'effBandGL': 0.0, 'effBandSH': 0.0, 'N_STREAM': 1, 'test': 3}, 'degme.mtx': {'Msparsity': 'C', 'Mtype': 'R', 'Mpattern': 'G', 'sort': 'SortR', 'blockSize': -1, 'mu': 0.000153, 'nMemAcGL': 0, 'nMemAcSH': 0, 'AI': 0.0, 'Iperf': 0.0, 'flops': 105.986954, 'effBandGL': 0.0, 'effBandSH': 0.0, 'N_STREAM': 1, 'test': 3}, 'mawi_201512012345.mtx': {'Msparsity': 'C', 'Mtype': 'I', 'Mpattern': 'S', 'sort': 'SortR', 'blockSize': -1, 'mu': 0.00056, 'nMemAcGL': 0, 'nMemAcSH': 0, 'AI': 0.0, 'Iperf': 0.0, 'flops': 67.93008, 'effBandGL': 0.0, 'effBandSH': 0.0, 'N_STREAM': 1, 'test': 1}, 'rail2586.mtx': {'Msparsity': 'C', 'Mtype': 'I', 'Mpattern': 'G', 'sort': 'SortR', 'blockSize': -1, 'mu': 0.000155, 'nMemAcGL': 0, 'nMemAcSH': 0, 'AI': 0.0, 'Iperf': 0.0, 'flops': 103.419246, 'effBandGL': 0.0, 'effBandSH': 0.0,
# ...

# %%
Results = {"id":[],"matrix":[],"sort":[],"blockSize":[],"mu":[],"nMemAcGL":[],"nMemAcSH":[],"AI":[],"Iperf":[],"flops":[],"effBandGL":[],"effBandSH":[],"N_STREAM":[],"test":[]}
#"test":[]
for matrix in ResultCOO_OLD:
    Results["id"].append("COO_OLD")
    Results["matrix"].append(matrix)
    Results["sort"].append(ResultCOO_OLD[matrix]["sort"])
    Results["blockSize"].append(ResultCOO_OLD[matrix]["blockSize"])
    Results["mu"].append(ResultCOO_OLD[matrix]["mu"])
    Results["nMemAcGL"].append(ResultCOO_OLD[matrix]["nMemAcGL"])
    Results["nMemAcSH"].append(ResultCOO_OLD[matrix]["nMemAcSH"])
    Results["AI"].append(ResultCOO_OLD[matrix]["AI"])
    Results["Iperf"].append(ResultCOO_OLD[matrix]["Iperf"])
    Results["flops"].append(ResultCOO_OLD[matrix]["flops"])
    Results["effBandGL"].append(ResultCOO_OLD[matrix]["effBandGL"])
    Results["effBandSH"].append(ResultCOO_OLD[matrix]["effBandSH"])
    Results["N_STREAM"].append(ResultCOO_OLD[matrix]["N_STREAM"])
    Results["test"].append(ResultCOO_OLD[matrix]["test"])

for matrix in ResultCOO_NEW_1:
    Results["id"].append("COO_NEW_1")
    Results["matrix"].append(matrix)
    Results["sort"].append(ResultCOO_NEW_1[matrix]["sort"])
    Results["blockSize"].append(ResultCOO_NEW_1[matrix]["blockSize"])
    Results["mu"].append(ResultCOO_NEW_1[matrix]["mu"])
    Results["nMemAcGL"].append(ResultCOO_NEW_1[matrix]["nMemAcGL"])
    Results["nMemAcSH"].append(ResultCOO_NEW_1[matrix]["nMemAcSH"])
    Results["AI"].append(ResultCOO_NEW_1[matrix]["AI"])
    Results["Iperf"].append(ResultCOO_NEW_1[matrix]["Iperf"])
    Results["flops"].append(ResultCOO_NEW_1[matrix]["flops"])
    Results["effBandGL"].append(ResultCOO_NEW_1[matrix]["effBandGL"])
    Results["effBandSH"].append(ResultCOO_NEW_1[matrix]["effBandSH"])
    Results["N_STREAM"].append(ResultCOO_NEW_1[matrix]["N_STREAM"])
    Results["test"].append(ResultCOO_NEW_1[matrix]["test"])

for matrix in ResultCOO_CUSPARSE:
    Results["id"].append("COO_CUSPARSE")
    Results["matrix"].append(matrix)
    Results["sort"].append(ResultCOO_CUSPARSE[matrix]["sort"])
    Results["blockSize"].append(ResultCOO_CUSPARSE[matrix]["blockSize"])
    Results["mu"].append(ResultCOO_CUSPARSE[matrix]["mu"])
    Results["nMemAcGL"].append(ResultCOO_CUSPARSE[matrix]["nMemAcGL"])
    Results["nMemAcSH"].append(ResultCOO_CUSPARSE[matrix]["nMemAcSH"])
    Results["AI"].append(ResultCOO_CUSPARSE[matrix]["AI"])
    Results["Iperf"].append(ResultCOO_CUSPARSE[matrix]["Iperf"])
    Results["flops"].append(ResultCOO_CUSPARSE[matrix]["flops"])
    Results["effBandGL"].append(ResultCOO_CUSPARSE[matrix]["effBandGL"])
    Results["effBandSH"].append(ResultCOO_CUSPARSE[matrix]["effBandSH"])
    Results["N_STREAM"].append(ResultCOO_CUSPARSE[matrix]["N_STREAM"])
    Results["test"].append(ResultCOO_CUSPARSE[matrix]["test"])


RdataF = pd.DataFrame(Results)
df = RdataF

fig, axes = plt.subplots(1, 2, figsize=(30, 12))
fields_to_plot = ["mu","flops"]

for ax, field in zip(axes.flatten(), fields_to_plot):
    pivot_df = df.pivot_table(index="matrix", columns="id", values=field, fill_value=0)
    pivot_df.sort_index(inplace=True)  # Optional: sort x-axis
    pivot_df.plot(kind="bar",ax=ax, figsize=(26, 5), color=colors)
    ax.set_xlabel("")
    ax.set_xticks([])
    if field == "mu":
        ax.set_ylabel("mu (s)",fontsize=40)
    if field == "flops":
        ax.set_ylabel("flops (GFLOPs)",fontsize=40)
    ax.tick_params(axis='y', labelsize=35)
    ax.legend().remove()

plt.legend(bbox_to_anchor=(0, 0, 1.6, 1), fontsize=30)
plt.show()

# %%
Results_1 = {"id":[],"matrix":[],"sort":[],"blockSize":[],"mu":[],"nMemAcGL":[],"nMemAcSH":[],"AI":[],"Iperf":[],"flops":[],"effBandGL":[],"effBandSH":[],"N_STREAM":[],"test":[]}
#"test":[]
for matrix in ResultCOO_OLD_1:
    Results_1["id"].append("COO_OLD")
    Results_1["matrix"].append(matrix)
    Results_1["sort"].append(ResultCOO_OLD_1[matrix]["sort"])
    Results_1["blockSize"].append(ResultCOO_OLD_1[matrix]["blockSize"])
    Results_1["mu"].append(ResultCOO_OLD_1[matrix]["mu"])
    Results_1["nMemAcGL"].append(ResultCOO_OLD_1[matrix]["nMemAcGL"])
    Results_1["nMemAcSH"].append(ResultCOO_OLD_1[matrix]["nMemAcSH"])
    Results_1["AI"].append(ResultCOO_OLD_1[matrix]["AI"])
    Results_1["Iperf"].append(ResultCOO_OLD_1[matrix]["Iperf"])
    Results_1["flops"].append(ResultCOO_OLD_1[matrix]["flops"])
    Results_1["effBandGL"].append(ResultCOO_OLD_1[matrix]["effBandGL"])
    Results_1["effBandSH"].append(ResultCOO_OLD_1[matrix]["effBandSH"])
    Results_1["N_STREAM"].append(ResultCOO_OLD_1[matrix]["N_STREAM"])
    Results_1["test"].append(ResultCOO_OLD_1[matrix]["test"])

for matrix in ResultCOO_NEW_1_1:
    Results_1["id"].append("COO_NEW_1")
    Results_1["matrix"].append(matrix)
    Results_1["sort"].append(ResultCOO_NEW_1_1[matrix]["sort"])
    Results_1["blockSize"].append(ResultCOO_NEW_1_1[matrix]["blockSize"])
    Results_1["mu"].append(ResultCOO_NEW_1_1[matrix]["mu"])
    Results_1["nMemAcGL"].append(ResultCOO_NEW_1_1[matrix]["nMemAcGL"])
    Results_1["nMemAcSH"].append(ResultCOO_NEW_1_1[matrix]["nMemAcSH"])
    Results_1["AI"].append(ResultCOO_NEW_1_1[matrix]["AI"])
    Results_1["Iperf"].append(ResultCOO_NEW_1_1[matrix]["Iperf"])
    Results_1["flops"].append(ResultCOO_NEW_1_1[matrix]["flops"])
    Results_1["effBandGL"].append(ResultCOO_NEW_1_1[matrix]["effBandGL"])
    Results_1["effBandSH"].append(ResultCOO_NEW_1_1[matrix]["effBandSH"])
    Results_1["N_STREAM"].append(ResultCOO_NEW_1_1[matrix]["N_STREAM"])
    Results_1["test"].append(ResultCOO_NEW_1_1[matrix]["test"])

for matrix in ResultCOO_CUSPARSE_1:
    Results_1["id"].append("COO_CUSPARSE")
    Results_1["matrix"].append(matrix)
    Results_1["sort"].append(ResultCOO_CUSPARSE_1[matrix]["sort"])
    Results_1["blockSize"].append(ResultCOO_CUSPARSE_1[matrix]["blockSize"])
    Results_1["mu"].append(ResultCOO_CUSPARSE_1[matrix]["mu"])
    Results_1["nMemAcGL"].append(ResultCOO_CUSPARSE_1[matrix]["nMemAcGL"])
    Results_1["nMemAcSH"].append(ResultCOO_CUSPARSE_1[matrix]["nMemAcSH"])
    Results_1["AI"].append(ResultCOO_CUSPARSE_1[matrix]["AI"])
    Results_1["Iperf"].append(ResultCOO_CUSPARSE_1[matrix]["Iperf"])
    Results_1["flops"].append(ResultCOO_CUSPARSE_1[matrix]["flops"])
    Results_1["effBandGL"].append(ResultCOO_CUSPARSE_1[matrix]["effBandGL"])
    Results_1["effBandSH"].append(ResultCOO_CUSPARSE_1[matrix]["effBandSH"])
    Results_1["N_STREAM"].append(ResultCOO_CUSPARSE_1[matrix]["N_STREAM"])
    Results_1["test"].append(ResultCOO_CUSPARSE_1[matrix]["test"])

Results_2 = {"id":[],"matrix":[],"sort":[],"blockSize":[],"mu":[],"nMemAcGL":[],"nMemAcSH":[],"AI":[],"Iperf":[],"flops":[],"effBandGL":[],"effBandSH":[],"N_STREAM":[],"test":[]}
#"test":[]
for matrix in ResultCOO_OLD_2:
    Results_2["id"].append("COO_OLD")
    Results_2["matrix"].append(matrix)
    Results_2["sort"].append(ResultCOO_OLD_2[matrix]["sort"])
    Results_2["blockSize"].append(ResultCOO_OLD_2[matrix]["blockSize"])
    Results_2["mu"].append(ResultCOO_OLD_2[matrix]["mu"])
    Results_2["nMemAcGL"].append(ResultCOO_OLD_2[matrix]["nMemAcGL"])
    Results_2["nMemAcSH"].append(ResultCOO_OLD_2[matrix]["nMemAcSH"])
    Results_2["AI"].append(ResultCOO_OLD_2[matrix]["AI"])
    Results_2["Iperf"].append(ResultCOO_OLD_2[matrix]["Iperf"])
    Results_2["flops"].append(ResultCOO_OLD_2[matrix]["flops"])
    Results_2["effBandGL"].append(ResultCOO_OLD_2[matrix]["effBandGL"])
    Results_2["effBandSH"].append(ResultCOO_OLD_2[matrix]["effBandSH"])
    Results_2["N_STREAM"].append(ResultCOO_OLD_2[matrix]["N_STREAM"])
    Results_2["test"].append(ResultCOO_OLD_2[matrix]["test"])

for matrix in ResultCOO_NEW_1_2:
    Results_2["id"].append("COO_NEW_1")
    Results_2["matrix"].append(matrix)
    Results_2["sort"].append(ResultCOO_NEW_1_2[matrix]["sort"])
    Results_2["blockSize"].append(ResultCOO_NEW_1_2[matrix]["blockSize"])
    Results_2["mu"].append(ResultCOO_NEW_1_2[matrix]["mu"])
    Results_2["nMemAcGL"].append(ResultCOO_NEW_1_2[matrix]["nMemAcGL"])
    Results_2["nMemAcSH"].append(ResultCOO_NEW_1_2[matrix]["nMemAcSH"])
    Results_2["AI"].append(ResultCOO_NEW_1_2[matrix]["AI"])
    Results_2["Iperf"].append(ResultCOO_NEW_1_2[matrix]["Iperf"])
    Results_2["flops"].append(ResultCOO_NEW_1_2[matrix]["flops"])
    Results_2["effBandGL"].append(ResultCOO_NEW_1_2[matrix]["effBandGL"])
    Results_2["effBandSH"].append(ResultCOO_NEW_1_2[matrix]["effBandSH"])
    Results_2["N_STREAM"].append(ResultCOO_NEW_1_2[matrix]["N_STREAM"])
    Results_2["test"].append(ResultCOO_NEW_1_2[matrix]["test"])

for matrix in ResultCOO_CUSPARSE_2:
    Results_2["id"].append("COO_CUSPARSE")
    Results_2["matrix"].append(matrix)
    Results_2["sort"].append(ResultCOO_CUSPARSE_2[matrix]["sort"])
    Results_2["blockSize"].append(ResultCOO_CUSPARSE_2[matrix]["blockSize"])
    Results_2["mu"].append(ResultCOO_CUSPARSE_2[matrix]["mu"])
    Results_2["nMemAcGL"].append(ResultCOO_CUSPARSE_2[matrix]["nMemAcGL"])
    Results_2["nMemAcSH"].append(ResultCOO_CUSPARSE_2[matrix]["nMemAcSH"])
    Results_2["AI"].append(ResultCOO_CUSPARSE_2[matrix]["AI"])
    Results_2["Iperf"].append(ResultCOO_CUSPARSE_2[matrix]["Iperf"])
    Results_2["flops"].append(ResultCOO_CUSPARSE_2[matrix]["flops"])
    Results_2["effBandGL"].append(ResultCOO_CUSPARSE_2[matrix]["effBandGL"])
    Results_2["effBandSH"].append(ResultCOO_CUSPARSE_2[matrix]["effBandSH"])
    Results_2["N_STREAM"].append(ResultCOO_CUSPARSE_2[matrix]["N_STREAM"])
    Results_2["test"].append(ResultCOO_CUSPARSE_2[matrix]["test"])

Rdata1 = pd.DataFrame(Results_1)
Rdata2 = pd.DataFrame(Results_2)
RdataStream = pd.concat([Rdata1, Rdata2], ignore_index=True)


df = RdataStream[RdataStream["id"] == "COO_NEW_1"]
fig, ax = plt.subplots(1, 1, figsize=(30, 12))
pivot_df = df.pivot_table(index="matrix", columns="N_STREAM", values="mu", fill_value=0)
pivot_df.sort_index(inplace=True)  # Optional: sort x-axis
pivot_df.plot(kind="bar",ax=ax, figsize=(26, 5), color=colors)
ax.set_xlabel("")
ax.set_xticks([])
ax.set_ylabel("mu",fontsize=40)

ax.tick_params(axis='y', labelsize=35)

plt.tight_layout()
plt.legend(bbox_to_anchor=(0, 0, 1, 1), fontsize=34)
plt.show()

# %%
dataNCU1 = pd.read_csv('../test/combined_ncu_report_new_1.csv')
datNCU1 = pd.DataFrame(dataNCU1)
datNCU1["test"] = 1
dataNCU2 = pd.read_csv('../test/combined_ncu_report_new_2.csv')
datNCU2 = pd.DataFrame(dataNCU2)
datNCU2["test"] = 3
dataNCU = pd.concat([datNCU1, datNCU2], ignore_index=True)
#dataNCU = pd.read_csv('../test/combined_ncu_report_new_1.csv')

# %%
fields_to_plot = ["Memory Throughput","DRAM Throughput","L1/TEX Cache Throughput","L2 Cache Throughput","Compute (SM) Throughput"]
dfo = pd.DataFrame(dataNCU)
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_reduce_update_kernel_mult_block"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_reduce_update_kernel_one_block"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_kernel_shared"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_serial_kernel"]
dfo = dfo[dfo["Kernel_N"] != "void cusparse::vector_scalar_multiply_kernel<cusparse::VectorWiseMulPolicy<"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_kernel_shared"]
dfo = dfo[dfo["Section_N"] == "GPU Speed Of Light Throughput"]

dfo.to_csv("my_data.csv", index=False)

matrices = ["BenElechi1.mtx", "degme.mtx", "mawi_201512012345.mtx","rail2586.mtx","specular.mtx"]

result = pd.DataFrame([])

for m in matrices:
    dfM = dfo[dfo["Matrix"] == m]
    dfo1 = dfM[(dfM["BLOCK_SIZE_P"] == ResultCOO_OLD[m]["blockSize"]) & (dfM["Solution"] == "COO_OLD") & (dfM["ITER"] == 1) & (dfM["Sort"] == ResultCOO_OLD[m]["sort"]) & (dfM["test"] == ResultCOO_OLD[m]["test"])]
    #(dfM["test"] == ResultCOO_OLD[m]["test"])
    dfo2 = dfM[(dfM["BLOCK_SIZE_P"] == ResultCOO_NEW_1[m]["blockSize"]) & (dfM["Solution"] == "COO_NEW_1") & (dfM["ITER"] == 1) & (dfM["test"] == ResultCOO_NEW_1[m]["test"])]
    #(dfM["test"] == ResultCOO_NEW_1[m]["test"])
    dfo3 = dfM[(dfM["Solution"] == "Cusparse") & (dfM["ITER"] == 1) & (dfM["test"] == ResultCOO_CUSPARSE[m]["test"])]
    #(dfM["test"] == ResultCOO_CUSPARSE[m]["test"])
    dfo1UN = pd.concat([dfo1, dfo2], ignore_index=True)
    dfo2UN = pd.concat([dfo1UN, dfo3], ignore_index=True)
    result = pd.concat([result, dfo2UN], ignore_index=True)

result['Metric_V'] = pd.to_numeric(result['Metric_V'], errors='coerce')

fig, axes = plt.subplots(3, 2, figsize=(60, 70))

for ax, field in zip(axes.flatten(), fields_to_plot):
    df = result[result["Metric_N"] == field]
    pivot_df = df.pivot_table(index="Matrix", columns="Solution", values="Metric_V", fill_value=0)
    pivot_df.plot(kind="bar",ax=ax, figsize=(26, 20), color=colors)
    ax.set_xlabel("")
    ax.set_xticks([])
    ax.set_ylabel(field,fontsize=35)
    ax.tick_params(axis='y', labelsize=35)
    ax.legend().remove()

fig.delaxes(axes[2][1])
plt.tight_layout()
plt.legend(bbox_to_anchor=(0, 0, 1.8, 0.7), fontsize=40)
plt.show()

# %%
fields_to_plot = ["Memory Throughput","Max Bandwidth","L1/TEX Hit Rate","L2 Hit Rate"]
dfo = pd.DataFrame(dataNCU)
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_reduce_update_kernel_mult_block"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_reduce_update_kernel_one_block"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_kernel_shared"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_serial_kernel"]
dfo = dfo[dfo["Kernel_N"] != "void cusparse::vector_scalar_multiply_kernel<cusparse::VectorWiseMulPolicy<"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_kernel_shared"]
dfo = dfo[dfo["Section_N"] == "Memory Workload Analysis"]

matrices = ["BenElechi1.mtx", "degme.mtx", "mawi_201512012345.mtx", "rail2586.mtx", "specular.mtx"]

result = pd.DataFrame([])

for m in matrices:
    dfM = dfo[dfo["Matrix"] == m]
    dfo1 = dfM[(dfM["BLOCK_SIZE_P"] == ResultCOO_OLD[m]["blockSize"]) & (dfM["Solution"] == "COO_OLD") & (dfM["ITER"] == 1) & (dfM["Sort"] == ResultCOO_OLD[m]["sort"]) & (dfM["test"] == ResultCOO_OLD[m]["test"])]
    dfo2 = dfM[(dfM["BLOCK_SIZE_P"] == ResultCOO_NEW_1[m]["blockSize"]) & (dfM["Solution"] == "COO_NEW_1") & (dfM["ITER"] == 1) & (dfM["test"] == ResultCOO_NEW_1[m]["test"])]
    dfo3 = dfM[(dfM["Solution"] == "Cusparse") & (dfM["ITER"] == 1) & (dfM["test"] == ResultCOO_CUSPARSE[m]["test"])]
    dfo1UN = pd.concat([dfo1, dfo2], ignore_index=True)
    dfo2UN = pd.concat([dfo1UN, dfo3], ignore_index=True)
    result = pd.concat([result, dfo2UN], ignore_index=True)

result['Metric_V'] = pd.to_numeric(result['Metric_V'], errors='coerce')

fig, axes = plt.subplots(1, 4, figsize=(60, 70))

for ax, field in zip(axes.flatten(), fields_to_plot):
    df = result[result["Metric_N"] == field]
    pivot_df = df.pivot_table(index="Matrix", columns="Solution", values="Metric_V", fill_value=0)
    pivot_df.plot(kind="bar", ax=ax, figsize=(29, 7), color=colors)
    ax.set_xlabel("")
    ax.set_xticks([])
    ax.set_ylabel(field, fontsize=40)
    ax.tick_params(axis='y', labelsize=35)
    ax.legend().remove()

plt.tight_layout()
plt.legend(bbox_to_anchor=(0, 0, 1.8, 1), fontsize=30)
plt.show()

# %%
fields_to_plot = ["Achieved Occupancy","Achieved Active Warps Per SM"]
dfo = pd.DataFrame(dataNCU)
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_reduce_update_kernel_mult_block"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_reduce_update_kernel_one_block"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_kernel_shared"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_serial_kernel"]
dfo = dfo[dfo["Kernel_N"] != "void cusparse::vector_scalar_multiply_kernel<cusparse::VectorWiseMulPolicy<"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_kernel_shared"]
dfo = dfo[dfo["Section_N"] == "Occupancy"]

matrices = ["BenElechi1.mtx", "degme.mtx", "mawi_201512012345.mtx", "rail2586.mtx", "specular.mtx"]

result = pd.DataFrame([])

for m in matrices:
    dfM = dfo[dfo["Matrix"] == m]
    dfo1 = dfM[(dfM["BLOCK_SIZE_P"] == ResultCOO_OLD[m]["blockSize"]) & (dfM["Solution"] == "COO_OLD") & (dfM["ITER"] == 1) & (dfM["Sort"] == ResultCOO_OLD[m]["sort"]) & (dfM["test"] == ResultCOO_OLD[m]["test"])]
    dfo2 = dfM[(dfM["BLOCK_SIZE_P"] == ResultCOO_NEW_1[m]["blockSize"]) & (dfM["Solution"] == "COO_NEW_1") & (dfM["ITER"] == 1) & (dfM["test"] == ResultCOO_NEW_1[m]["test"])]
    dfo3 = dfM[(dfM["Solution"] == "Cusparse") & (dfM["ITER"] == 1) & (dfM["test"] == ResultCOO_CUSPARSE[m]["test"])]
    dfo1UN = pd.concat([dfo1, dfo2], ignore_index=True)
    dfo2UN = pd.concat([dfo1UN, dfo3], ignore_index=True)
    result = pd.concat([result, dfo2UN], ignore_index=True)

result['Metric_V'] = pd.to_numeric(result['Metric_V'], errors='coerce')

fig, axes = plt.subplots(1, 2, figsize=(60, 70))

for ax, field in zip(axes.flatten(), fields_to_plot):
    df = result[result["Metric_N"] == field]
    pivot_df = df.pivot_table(index="Matrix", columns="Solution", values="Metric_V", fill_value=0)
    pivot_df.plot(kind="bar", ax=ax, figsize=(26, 10), color=colors)
    ax.set_xlabel("")
    ax.set_xticks([])
    ax.set_ylabel(field, fontsize=40)
    ax.tick_params(axis='y', labelsize=35)
    ax.legend().remove()

plt.tight_layout()
plt.legend(bbox_to_anchor=(0, 0, 1.4, 1), fontsize=30)
plt.show()

# %%
fields_to_plot = ["Active Warps Per Scheduler","Eligible Warps Per Scheduler","Issued Warp Per Scheduler"]
dfo = pd.DataFrame(dataNCU)
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_reduce_update_kernel_mult_block"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_reduce_update_kernel_one_block"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_kernel_shared"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_serial_kernel"]
dfo = dfo[dfo["Kernel_N"] != "void cusparse::vector_scalar_multiply_kernel<cusparse::VectorWiseMulPolicy<"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_kernel_shared"]
dfo = dfo[dfo["Section_N"] == "Scheduler Statistics"]

matrices = ["BenElechi1.mtx", "degme.mtx", "mawi_201512012345.mtx", "rail2586.mtx", "specular.mtx"]

result = pd.DataFrame([])

for m in matrices:
    dfM = dfo[dfo["Matrix"] == m]
    dfo1 = dfM[(dfM["BLOCK_SIZE_P"] == ResultCOO_OLD[m]["blockSize"]) & (dfM["Solution"] == "COO_OLD") & (dfM["ITER"] == 1) & (dfM["Sort"] == ResultCOO_OLD[m]["sort"]) & (dfM["test"] == ResultCOO_OLD[m]["test"])]
    dfo2 = dfM[(dfM["BLOCK_SIZE_P"] == ResultCOO_NEW_1[m]["blockSize"]) & (dfM["Solution"] == "COO_NEW_1") & (dfM["ITER"] == 1) & (dfM["test"] == ResultCOO_NEW_1[m]["test"])]
    dfo3 = dfM[(dfM["Solution"] == "Cusparse") & (dfM["ITER"] == 1) & (dfM["test"] == ResultCOO_CUSPARSE[m]["test"])]
    dfo1UN = pd.concat([dfo1, dfo2], ignore_index=True)
    dfo2UN = pd.concat([dfo1UN, dfo3], ignore_index=True)
    result = pd.concat([result, dfo2UN], ignore_index=True)

result['Metric_V'] = pd.to_numeric(result['Metric_V'], errors='coerce')

fig, axes = plt.subplots(1, 3, figsize=(60, 70))

for ax, field in zip(axes.flatten(), fields_to_plot):
    df = result[result["Metric_N"] == field]
    pivot_df = df.pivot_table(index="Matrix", columns="Solution", values="Metric_V", fill_value=0)
    pivot_df.plot(kind="bar", ax=ax, figsize=(26, 7), color=colors)
    ax.set_xlabel("")
    ax.set_xticks([])
    ax.set_ylabel(field, fontsize=35)
    ax.tick_params(axis='y', labelsize=35)
    ax.legend().remove()

plt.tight_layout()
plt.legend(bbox_to_anchor=(0, 0, 1.65, 1), fontsize=30)
plt.show()

# %%
fields_to_plot = ["Warp Cycles Per Issued Instruction","Warp Cycles Per Executed Instruction","Avg. Active Threads Per Warp","Avg. Not Predicated Off Threads Per Warp"]
dfo = pd.DataFrame(dataNCU)
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_reduce_update_kernel_mult_block"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_reduce_update_kernel_one_block"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_kernel_shared"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_serial_kernel"]
dfo = dfo[dfo["Kernel_N"] != "void cusparse::vector_scalar_multiply_kernel<cusparse::VectorWiseMulPolicy<"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_kernel_shared"]
dfo = dfo[dfo["Section_N"] == "Warp State Statistics"]

matrices = ["BenElechi1.mtx", "degme.mtx", "mawi_201512012345.mtx", "rail2586.mtx", "specular.mtx"]

result = pd.DataFrame([])

for m in matrices:
    dfM = dfo[dfo["Matrix"] == m]
    dfo1 = dfM[(dfM["BLOCK_SIZE_P"] == ResultCOO_OLD[m]["blockSize"]) & (dfM["Solution"] == "COO_OLD") & (dfM["ITER"] == 1) & (dfM["Sort"] == ResultCOO_OLD[m]["sort"]) & (dfM["test"] == ResultCOO_OLD[m]["test"])]
    dfo2 = dfM[(dfM["BLOCK_SIZE_P"] == ResultCOO_NEW_1[m]["blockSize"]) & (dfM["Solution"] == "COO_NEW_1") & (dfM["ITER"] == 1) & (dfM["test"] == ResultCOO_NEW_1[m]["test"])]
    dfo3 = dfM[(dfM["Solution"] == "Cusparse") & (dfM["ITER"] == 1) & (dfM["test"] == ResultCOO_CUSPARSE[m]["test"])]
    dfo1UN = pd.concat([dfo1, dfo2], ignore_index=True)
    dfo2UN = pd.concat([dfo1UN, dfo3], ignore_index=True)
    result = pd.concat([result, dfo2UN], ignore_index=True)

result['Metric_V'] = pd.to_numeric(result['Metric_V'], errors='coerce')

fig, axes = plt.subplots(1, 4, figsize=(60, 70))

for ax, field in zip(axes.flatten(), fields_to_plot):
    df = result[result["Metric_N"] == field]
    pivot_df = df.pivot_table(index="Matrix", columns="Solution", values="Metric_V", fill_value=0)
    pivot_df.plot(kind="bar", ax=ax, figsize=(29, 10), color=colors)
    ax.set_xlabel("")
    ax.set_xticks([])
    ax.set_ylabel(field, fontsize=35)
    ax.tick_params(axis='y', labelsize=35)
    ax.legend().remove()

plt.tight_layout()
plt.legend(bbox_to_anchor=(0, 0, 1.8, 1), fontsize=30)
plt.show()

# %%
fields_to_plot = ["Executed Ipc Active","Executed Ipc Elapsed","Issue Slots Busy","Issued Ipc Active","SM Busy"]
dfo = pd.DataFrame(dataNCU)
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_reduce_update_kernel_mult_block"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_reduce_update_kernel_one_block"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_kernel_shared"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_serial_kernel"]
dfo = dfo[dfo["Kernel_N"] != "void cusparse::vector_scalar_multiply_kernel<cusparse::VectorWiseMulPolicy<"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_kernel_shared"]
dfo = dfo[dfo["Section_N"] == "Compute Workload Analysis"]

matrices = ["BenElechi1.mtx", "degme.mtx", "mawi_201512012345.mtx", "rail2586.mtx", "specular.mtx"]

result = pd.DataFrame([])

for m in matrices:
    dfM = dfo[dfo["Matrix"] == m]
    dfo1 = dfM[(dfM["BLOCK_SIZE_P"] == ResultCOO_OLD[m]["blockSize"]) & (dfM["Solution"] == "COO_OLD") & (dfM["ITER"] == 1) & (dfM["Sort"] == ResultCOO_OLD[m]["sort"]) & (dfM["test"] == ResultCOO_OLD[m]["test"])]
    dfo2 = dfM[(dfM["BLOCK_SIZE_P"] == ResultCOO_NEW_1[m]["blockSize"]) & (dfM["Solution"] == "COO_NEW_1") & (dfM["ITER"] == 1) & (dfM["test"] == ResultCOO_NEW_1[m]["test"])]
    dfo3 = dfM[(dfM["Solution"] == "Cusparse") & (dfM["ITER"] == 1) & (dfM["test"] == ResultCOO_CUSPARSE[m]["test"])]
    dfo1UN = pd.concat([dfo1, dfo2], ignore_index=True)
    dfo2UN = pd.concat([dfo1UN, dfo3], ignore_index=True)
    result = pd.concat([result, dfo2UN], ignore_index=True)

result['Metric_V'] = pd.to_numeric(result['Metric_V'], errors='coerce')

fig, axes = plt.subplots(3, 2, figsize=(60, 70))

for ax, field in zip(axes.flatten(), fields_to_plot):
    df = result[result["Metric_N"] == field]
    pivot_df = df.pivot_table(index="Matrix", columns="Solution", values="Metric_V", fill_value=0)
    pivot_df.plot(kind="bar", ax=ax, figsize=(26, 20), color=colors)
    ax.set_xlabel("")
    ax.set_xticks([])
    ax.set_ylabel(field, fontsize=40)
    ax.tick_params(axis='y', labelsize=35)
    ax.legend().remove()

fig.delaxes(axes[2][1])
plt.tight_layout()
plt.legend(bbox_to_anchor=(0, 0, 1.8, 0.7), fontsize=40)
plt.show()

# %%
fields_to_plot = ["Branch Instructions Ratio","Branch Efficiency"]
dfo = pd.DataFrame(dataNCU)
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_reduce_update_kernel_mult_block"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_reduce_update_kernel_one_block"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_kernel_shared"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_serial_kernel"]
dfo = dfo[dfo["Kernel_N"] != "void cusparse::vector_scalar_multiply_kernel<cusparse::VectorWiseMulPolicy<"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_kernel_shared"]
dfo = dfo[dfo["Section_N"] == "Source Counters"]

matrices = ["BenElechi1.mtx", "degme.mtx", "mawi_201512012345.mtx", "rail2586.mtx", "specular.mtx"]

result = pd.DataFrame([])

for m in matrices:
    dfM = dfo[dfo["Matrix"] == m]
    dfo1 = dfM[(dfM["BLOCK_SIZE_P"] == ResultCOO_OLD[m]["blockSize"]) & (dfM["Solution"] == "COO_OLD") & (dfM["ITER"] == 1) & (dfM["Sort"] == ResultCOO_OLD[m]["sort"]) & (dfM["test"] == ResultCOO_OLD[m]["test"])]
    dfo2 = dfM[(dfM["BLOCK_SIZE_P"] == ResultCOO_NEW_1[m]["blockSize"]) & (dfM["Solution"] == "COO_NEW_1") & (dfM["ITER"] == 1) & (dfM["test"] == ResultCOO_NEW_1[m]["test"])]
    dfo3 = dfM[(dfM["Solution"] == "Cusparse") & (dfM["ITER"] == 1) & (dfM["test"] == ResultCOO_CUSPARSE[m]["test"])]
    dfo1UN = pd.concat([dfo1, dfo2], ignore_index=True)
    dfo2UN = pd.concat([dfo1UN, dfo3], ignore_index=True)
    result = pd.concat([result, dfo2UN], ignore_index=True)

result['Metric_V'] = pd.to_numeric(result['Metric_V'], errors='coerce')

fig, axes = plt.subplots(1, 2, figsize=(60, 30))

for ax, field in zip(axes.flatten(), fields_to_plot):
    df = result[result["Metric_N"] == field]
    pivot_df = df.pivot_table(index="Matrix", columns="Solution", values="Metric_V", fill_value=0)
    pivot_df.plot(kind="bar", ax=ax, figsize=(26, 9), color=colors)
    ax.set_xlabel("")
    ax.set_xticks([])
    ax.set_ylabel(field, fontsize=40)
    ax.tick_params(axis='y', labelsize=35)
    ax.legend().remove()

plt.tight_layout()
plt.legend(bbox_to_anchor=(0, 0, 1.4, 1), fontsize=30)
plt.show()

# %%
dfo = pd.DataFrame(dataNCU)
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_reduce_update_kernel_mult_block"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_reduce_update_kernel_one_block"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_kernel_shared"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_serial_kernel"]
dfo = dfo[dfo["Kernel_N"] != "void cusparse::vector_scalar_multiply_kernel<cusparse::VectorWiseMulPolicy<"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_kernel_shared"]
dfo = dfo[dfo["Solution"] != "Cusparse"]
dfo = dfo[dfo["Section_N"] == "Occupancy"]
dfo = dfo[dfo["Metric_N"] == "Theoretical Occupancy"]

matrices = ["BenElechi1.mtx", "degme.mtx", "mawi_201512012345.mtx", "rail2586.mtx", "specular.mtx"]

result = pd.DataFrame([])

for m in matrices:
    dfM = dfo[dfo["Matrix"] == m]
    dfo1 = dfM[(dfM["BLOCK_SIZE_P"] == ResultCOO_OLD[m]["blockSize"]) & (dfM["Solution"] == "COO_OLD") & (dfM["ITER"] == 1) & (dfM["Sort"] == ResultCOO_OLD[m]["sort"]) & (dfM["test"] == ResultCOO_OLD[m]["test"])]
    dfo2 = dfM[(dfM["BLOCK_SIZE_P"] == ResultCOO_NEW_1[m]["blockSize"]) & (dfM["Solution"] == "COO_NEW_1") & (dfM["ITER"] == 1) & (dfM["test"] == ResultCOO_NEW_1[m]["test"])]
    dfo3 = dfM[(dfM["Solution"] == "Cusparse") & (dfM["ITER"] == 1) & (dfM["test"] == ResultCOO_CUSPARSE[m]["test"])]
    dfo1UN = pd.concat([dfo1, dfo2], ignore_index=True)
    dfo2UN = pd.concat([dfo1UN, dfo3], ignore_index=True)
    result = pd.concat([result, dfo2UN], ignore_index=True)

result['BLOCK_SIZE_P'] = pd.to_numeric(result['BLOCK_SIZE_P'], errors='coerce')

fig, ax = plt.subplots(1, 1, figsize=(60, 70))

pivot_df = result.pivot_table(index="Matrix", columns="Solution", values="BLOCK_SIZE_P", fill_value=0)
pivot_df.plot(kind="bar",ax=ax, figsize=(26, 7), color=colors)
ax.set_xlabel("")
ax.set_xticks([])
ax.set_ylabel("BLOCK_SIZE",fontsize=40)
ax.tick_params(axis='y', labelsize=35)
ax.legend(fontsize=40)

plt.tight_layout()
plt.show()

# %%
fields_to_plot = ["Block Size", "Grid Size", "Registers Per Thread",
                  "Shared Memory Configuration Size","Driver Shared Memory Per Block","Dynamic Shared Memory Per Block","Static Shared Memory Per Block","# SMs","Threads","Waves Per SM"]
dfo = pd.DataFrame(dataNCU)
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_reduce_update_kernel_mult_block"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_reduce_update_kernel_one_block"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_kernel_shared"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_serial_kernel"]
dfo = dfo[dfo["Kernel_N"] != "void cusparse::vector_scalar_multiply_kernel<cusparse::VectorWiseMulPolicy<"]
dfo = dfo[dfo["Kernel_N"] != "spmv_coo_kernel_shared"]
dfo = dfo[dfo["Section_N"] == "Launch Statistics"]

matrices = ["BenElechi1.mtx", "degme.mtx", "mawi_201512012345.mtx", "rail2586.mtx", "specular.mtx"]

result = pd.DataFrame([])

for m in matrices:
    dfM = dfo[dfo["Matrix"] == m]
    dfo1 = dfM[(dfM["BLOCK_SIZE_P"] == ResultCOO_OLD[m]["blockSize"]) & (dfM["Solution"] == "COO_OLD") & (dfM["ITER"] == 1) & (dfM["Sort"] == ResultCOO_OLD[m]["sort"]) & (dfM["test"] == ResultCOO_OLD[m]["test"])]
    dfo2 = dfM[(dfM["BLOCK_SIZE_P"] == ResultCOO_NEW_1[m]["blockSize"]) & (dfM["Solution"] == "COO_NEW_1") & (dfM["ITER"] == 1) & (dfM["test"] == ResultCOO_NEW_1[m]["test"])]
    dfo3 = dfM[(dfM["Solution"] == "Cusparse") & (dfM["ITER"] == 1) & (dfM["test"] == ResultCOO_CUSPARSE[m]["test"])]
    dfo1UN = pd.concat([dfo1, dfo2], ignore_index=True)
    dfo2UN = pd.concat([dfo1UN, dfo3], ignore_index=True)
    result = pd.concat([result, dfo2UN], ignore_index=True)

result['Metric_V'] = pd.to_numeric(result['Metric_V'], errors='coerce')

result = result.drop([ 'Stream','Block_S','Grid_S','Section_N','N_STREAM','ITER'], axis=1)

# Convert to LaTeX
latex_table = result.to_latex(index=False)  # Set index=True if you want the index column

# Save to .tex file
with open('table.tex', 'w') as f:
    f.write(latex_table)
